# %%
 # WARM - UP
    
a = int(input("enter first number" ))
b = int(input("enter second number" ))
c = int(input("enter third number" ))
print("max_num is", " ")

if (a>=b) and (a>=c):
    print(a)
    
elif (b>=a) and (b>=c):
    print(b)
    
else:
    print(c)
# Out:
# enter first number2
# enter second number3
# enter third number4
# max_num is
# 4

# %%
import pandas as pd
import numpy as np
from scipy import stats
file_to_load = "belize_airbnb_listings.csv"
df = pd.read_csv(file_to_load)
df1 = pd.DataFrame(df)
df1
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1        36690  Mo's Cozy Cabana w/ comfy veranda & access to ...     157752
# 2       108932  Purple House eco solar  w/ ocean & wildlife views     563377
# 3       110483                            Michelo's fuchsia suite     567809
# 4       120115               Seaside Villas Second Floor Unit  #4     604999
# ...        ...                                                ...        ...
# 2791  48283996                                     Magical Island   17994012
# 2792  48287613   The Luxury Suite - Corozal, Bz- 3Bdr/2bthr CASA1  375769845
# 2793  48296096  Lagoon front apartment w/shared pool -  two mi...   76414486
# 2794  48296978                          Beachfront Poolside Condo   15308338
# 2795  48332221           Standard Room - San Ignacio Resort Hotel   60399527
#
# ...

# %% [markdown]
# # Arithmetic mean

# %% [markdown]
# Arithmetic mean is sum of the values divided by the total number of values.

# %%
df1[["price","reviews_per_month","availability_365"]].mean()
# Out:
# price                357.102289
# reviews_per_month      0.538088
# availability_365     280.315451
# dtype: float64

# %% [markdown]
# # Geomertic mean

# %%
geometric mean is the N-th root of the product of all values, where N is the number of values.

# %%
print(stats.gmean(df1["minimum_nights"]))
# Out:
# 1.693257141902733

# %% [markdown]
# # Harmonic mean

# %%
Harmonic mean is number of values divides by the sum of the reciprocal of the values.

# %%
print(stats.hmean(df1["price"]))
# Out:
# 170.99338501026463

# %%
# 2 QUESTION
list_word = []
def append_sort():
    #global list_word
    list_word.append(input("enter word", ))
    list_word.sort()
    print(list_word)

i=0
j = int(input("How many words do you need to sort? Please enter a number"))
while i < j:
    
    append_sort()
    i+=1
# Out:
# How many words do you need to sort? Please enter a number3
# enter wordbanana
# ['banana']
# enter wordapple
# ['apple', 'banana']
# enter wordcarrot
# ['apple', 'banana', 'carrot']
